# %% [markdown]
# ## Why Python Built-In Data Structure?
# * To collect multiple data in a structure
#
# #### 4 Data Structures in Phthon
# 1. List
# 2. Sets
# 3. Tuples
# 4. Dictionary - Key & Value

# %% [markdown]
# ## 1. List
# * 1D
# * Hetrogenous(collection of muliple data typs)
# * Dupliate Values
# * Indexing & Slicing is possible

# %%
empty_card = []

# %%
type(empty_card)
# Out:
# list

# %%
items_to_buy = ["Banana","Apple","Grape","Orange","Banana",8.9,43]
items_to_buy
# Out:
# ['Banana', 'Apple', 'Grape', 'Orange', 'Banana', 8.9, 43]

# %%
type(items_to_buy)
# Out:
# list

# %%
len(items_to_buy)
# Out:
# 7

# %%
items_to_buy[3]
# Out:
# 'Orange'

# %%
items_to_buy[-5]
# Out:
# 'Grape'

# %%
items_to_buy[2:5] #end index is not included
# Out:
# ['Grape', 'Orange', 'Banana']

# %%
items_to_buy[-2:-1] #end index is not included
# Out:
# [8.9]

# %%
items_to_buy[-2:] #to include end index, leave it blank
# Out:
# [8.9, 43]
